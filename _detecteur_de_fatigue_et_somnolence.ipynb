# %% [markdown]
# <a href="https://colab.research.google.com/github/arwa-mili/Coolab/blob/main/_detecteur_de_fatigue_et_somnolence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
img_array=cv2.imread("/content/s0001_00002_0_0_0_0_0_01.png",cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_array,cmap="gray")

# %%
img_array.shape
# Out:
# (84, 84)

# %%
 

Datadirectory = "Test_Dataset/" ## training dataset
Classes = ["Closed_Eyes","Open_Eyes"] ## List of classes
for category in Classes:
    path = os.path.join(Datadirectory, category) ## //
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        backtorgb = cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)
        plt.imshow(img array, cmap="gray")
        plt.show()
        break
    break
# Out:
#   File "<ipython-input-28-7abebaa4417c>", line 8
#     plt.imshow(img array, cmap="gray")
#                    ^
# SyntaxError: invalid syntax

# %%
img_size= 224
new_array=cv2.resize(backtorgb,(img_size,img_size))
plt.imshow(img array, cmap="gray")
plt.show()
# Out:
#   File "<ipython-input-29-b832288a4fee>", line 3
#     plt.imshow(img array, cmap="gray")
#                    ^
# SyntaxError: invalid syntax

# %%
training_Data = []

def create_training_Data():
    for category in Classes:
      path = os.path.join(Datadirectory, category)
      class_num = Classes. index(category) ## @ 1,
      for ing in os.listdir(path):
         try:
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
            backtorgb = cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)
            new_array= cv2.resize(backtorgb, (img_size,img_size))
            training_Data.append([new_array,class_num])
         except Exception as e:
            pass

# %%
create_training_Data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-ae09bcc94f2f> in <module>
# ----> 1 create_training_Data()
#
# <ipython-input-30-31c14de59452> in create_training_Data()
#       2
#       3 def create_training_Data():
# ----> 4     for category in Classes:
#       5       path = os.path.join(Datadirectory, category)
#       6       class_num = Classes. index(category) ## @ 1,
#
# NameError: name 'Classes' is not defined

# %%
print(len(training_Data))
# Out:
# 0

# %%
import random
random.shuffle(training_Data)

# %%
X = []
y = []
for features, label in training_Data:
     X.append(features)
     y.append(label)

X = np.array(X).reshape(-1,img_size,img_size,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-3ab329dca523> in <module>
#       5      Y.append(label)
#       6
# ----> 7 X = np.array(X).reshape(-1,img_size,img_size,3)
#       8
#       9
#
# NameError: name 'img_size' is not defined

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-bc5f1a0adac8> in <module>
# ----> 1 X.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
#normalize the data
X = X/255.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-e79805f2794b> in <module>
#       1 #normalize the data
# ----> 2 X = X/255.0
#
# TypeError: unsupported operand type(s) for /: 'list' and 'float'

# %%
Y= np.array(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-e34c9185b334> in <module>
# ----> 1 Y= np.array(y)
#
# NameError: name 'y' is not defined

# %%
import pickle
pickle_out = open("X. pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()



pickle_out = open("y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-2b452c8ad36c> in <module>
#       7
#       8 pickle_out = open("y.pickle","wb")
# ----> 9 pickle.dump(y, pickle_out)
#      10 pickle_out.close()
#      11
#
# NameError: name 'y' is not defined

# %%
pickle_in = open("X.pickle","rb")
X = pickle. load(pickle_in)

 
pickle_in = open("y.pickle","rb")
y = pickle. load(pickle_in)

# %% [markdown]
# ##Deep learning model for training

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = tf.keras.applications.mobilenet.MobileNet()

# %%
model.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
# ...

# %%
base_input = model.layers[0].input 

base_output = model. layers[-4].output

Flat_layer= layers.Flatten()(base_output)
final_output = layers.Dense(1)(Flat_layer) 
final_ouput = layers.Activation('sigmoid')(final_output)

# %%
new_model = keras.Model(inputs = base_input, outputs= final_output)

# %%
new_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
# ...

# %% [markdown]
# ##Binary classification (open/closed)

# %%
new_model.compile(1oss="binary_crossentropy”, optimizer = "adam", metrics = ["accuracy"])
# Out:
#   File "<ipython-input-51-35bd37810206>", line 1
#     new_model.compile(1oss="binary_crossentropy”, optimizer = "adam", metrics = ["accuracy"])
#                        ^
# SyntaxError: invalid syntax

# %%
new_model.fit(X,Y, epochs = 1,validation_split = 0.1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-52-197194cbe6a8> in <module>
# ----> 1 new_model.fit(X,Y, epochs = 1,validation_split = 0.1)
#       2
#       3
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in _assert_compile_was_called(self)
#    3158     # (i.e. whether the model is built and its inputs/outputs are set).
#    3159     if not self._is_compiled:
# -> 3160       raise RuntimeError('You must compile your model before '
# ...

# %%
new_model.save("my_model.h5")

new_model = tf.keras.models.load_model('my_model_Drowsiness.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-53-5d562c6c4332> in <module>
#       1 new_model.save("my_model.h5")
#       2
# ----> 3 new_model = tf.keras.models.load_model('my_model_Drowsiness.h5')
#       4
#       5
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ...

# %%
img_array = cv2.imread('/content/s0001_00002_0_2_0_0_1_01.png', cv2.IMREAD_GRAYSCALE)
backtorgb = cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)
new_array= cv2.resize(backtorgb, (img_size,img_size))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-f70d7880cbd3> in <module>
#       1 img_array = cv2.imread('/content/s0001_00002_0_0_0_0_0_01.png', cv2.IMREAD_GRAYSCALE)
#       2 backtorgb = cv2.cvtColor(img_array,cv2.COLOR_GRAY2RGB)
# ----> 3 new_array= cv2.resize(backtorgb, (img_size,img_size))
#       4
#       5
#
# NameError: name 'img_size' is not defined

# %%
X_input = np.array(new_array).reshape(1, img size, img size, 3)
# Out:
#   File "<ipython-input-56-706074300fc9>", line 1
#     X_input = np.array(new_array).reshape(1, img size, img size, 3)
#                                                  ^
# SyntaxError: invalid syntax

# %%
X_imput.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-98c2e24d28e9> in <module>
# ----> 1 X_imput.shape
#
# NameError: name 'X_imput' is not defined

# %%
plt.imshow(new_array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-1fb4be517bb9> in <module>
# ----> 1 plt.imshow(new_array)
#
# NameError: name 'new_array' is not defined

# %%
X_input = X_input/255.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-5028b0160c99> in <module>
# ----> 1 X_input = X_input/255.0
#
# NameError: name 'X_input' is not defined

# %%
prediction = new_model.predict(X_input)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-c757ab2d23c8> in <module>
# ----> 1 prediction = new_model.predict(X_input)
#       2
#       3
#       4
#       5
#
# NameError: name 'X_input' is not defined

# %%
prediction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-c3d8c93f720f> in <module>
# ----> 1 prediction
#
# NameError: name 'prediction' is not defined

# %%
img =cv2.read("sad_women.jpg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-112c2e06b8f2> in <module>
# ----> 1 img =cv2.read("sad_women.jpg")
#
# AttributeError: module 'cv2' has no attribute 'read'

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-d91f51c49baf> in <module>
# ----> 1 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB) )
#       2
#       3
#
# NameError: name 'img' is not defined

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

eyes = eye cascade. detectMultiScale(gray,1.1,4)

for(x, y, w, h) in eyes: 
    ev2.rectangle(img, (x, y), (xtw, y+h), (0, 255, 0), 2)
# Out:
#   File "<ipython-input-67-a9cee57c35ee>", line 3
#     eyes = eye cascade. detectMultiScale(gray,1.1,4)
#                ^
# SyntaxError: invalid syntax

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-d91f51c49baf> in <module>
# ----> 1 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB) )
#       2
#       3
#
# NameError: name 'img' is not defined

# %%
eye_cascade = cv2,CascadeClassifier(cv2.data.haarcascades +'haarcascade_eye.xml')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())
eyes = eye _cascade.detectMultiScale(gray,1.1,4)
for x,y,w,h in eyes:
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = imgly:y+h, x:x+w]
    eyess = eye_cascade.detectMultiscale(roi_gray)
    if len(eyess) == 0:
         print("eyes are not detected”)
    else:
        for (ex,ey,ew,eh) in eyess:

             eyes_roi = roi_color[ey: eyteh, ex:ex + ew]
# Out:
#   File "<ipython-input-69-ecdb8aa37c6d>", line 5
#     eyes = eye _cascade.detectMultiScale(gray,1.1,4)
#                ^
# SyntaxError: invalid syntax

# %%
final_image =cv2.resize(eyes_roi, (224,224))
final_image = np.expand_dims(final_image,axis =0) ## need fourth dimension
final_image=final_image/255.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-fe6190d2f8c3> in <module>
# ----> 1 final_image =cv2.resize(eyes_roi, (224,224))
#       2 final_image = np.expand_dims(final_image,axis =0) ## need fourth dimension
#       3 final_image=final_image/255.0
#       4
#       5
#
# NameError: name 'eyes_roi' is not defined

# %%
final_image.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-32509e0b1300> in <module>
# ----> 1 final_image.shape
#
# NameError: name 'final_image' is not defined

# %%
new_model.predict(final_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-87531677fb04> in <module>
# ----> 1 new_model.predict(final_image)
#
# NameError: name 'final_image' is not defined

# %%
import cv2 ### pip install opencv-python

## pip install opencv-contrib-python fullpackage

#from deepface import DeepFace ## pip install deepface

path = "haarcascade_frontalface_default.xml"

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + ‘haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)
# Check if the webcam is opened correctly
if not cap.isOpened():
   cap = cv2.VideoCapture(0)
if not cap.isOpened():
 raise IOError("Cannot open webcam")

while True:
  

while True:
    ret, frame = cap.read()
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_eye.xml')
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())
   eyes = eye_cascade.detectMultiScale(gray,1.1,4)
for x,y,w,h in eyes:
    roi_gray = gray[y:yth, x:x+w]
    roi_color = frame[y:yth, x:x+w]
    cv2.rectangle(frame, (x, y), (x+w, y+h), (@, 255, @), 2)
    eyess = eye_cascade.detectMultiScale(roi_gray)
    if len(eyess) == 0:
           print("eyes are not detected")
    else: 
      for (ex,ey,ew,eh) in eyes:
          eyes_roi = roi_colorfey: eyseh, ex:ex + ew]

final_image =cv2.resize(eyes_roi, (224,224))
final_image = np.expand_dims(final_image,axis -8) ## need fourth dimension
final_image=final_image/255.0
Predictions = new_model.predict(final_image)
if (Predictions>0):
    status = "Open Eyes”
else:
    status = "Closed Eyes”

gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
print(faceCascade.empty())

faces = faceCascade.detectMultiscale(gray,1.1,4)
# Draw a rectangle around the faces

for(x,y,w,h) in faces :
    cv2.rectangle(frame, (x, y), (x*W, yth), (®, 255, 0), 2)

 

font = cv2.FONT_HERSHEY_SIMPLEX
cv2.imshow( "Tiredness Detection " ,frame)

if cv2.waitKey(2) & 0xFF == ord("q"):
      break
cap.release()
cv2.destroyAllwindows()
